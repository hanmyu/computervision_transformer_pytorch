# %%
#먼저 본인의 googledrive에 coco.zip 파일을 넣어줌(압축 안 푼 것 넣기! 압축 푼 것 넣지 마세요)
#coco.zip파일은 https://www.kaggle.com/datasets/s076923/pytorch-transformer에서 다운로드(wget http://images.cocodataset.org/zips/val2017.zip로 따로 받지 마세요)
#googledrive을 google colab에 마운트.
#압축을 풀어서 코랩에 train, val, annotations 파일을 생성.
# !unzip /content/drive/MyDrive/CV_study/Coco_dataset/coco.zip
# Out:
# Archive:  /content/drive/MyDrive/CV_study/Coco_dataset/coco.zip
#   inflating: annotations/train_annotations.json
#   inflating: annotations/val_annotations.json
#   inflating: train/000000000042.jpg
#   inflating: train/000000000074.jpg
#  extracting: train/000000000400.jpg
#   inflating: train/000000000599.jpg
#   inflating: train/000000000675.jpg
#  extracting: train/000000000711.jpg
#   inflating: train/000000001319.jpg
#  extracting: train/000000001398.jpg
#   inflating: train/000000002295.jpg
#  extracting: train/000000002477.jpg
#   inflating: train/000000002753.jpg
#   inflating: train/000000002988.jpg
#  extracting: train/000000003067.jpg
#  extracting: train/000000003711.jpg
#  extracting: train/000000004212.jpg
#  extracting: train/000000004678.jpg
#  extracting: train/000000005105.jpg
#  extracting: train/000000005577.jpg
#  extracting: train/000000005617.jpg
#  extracting: train/000000005804.jpg
#   inflating: train/000000006397.jpg
#   inflating: train/000000006589.jpg
#   inflating: train/000000007125.jpg
#  extracting: train/000000007414.jpg
#   inflating: train/000000007722.jpg
#   inflating: train/000000007730.jpg
#   inflating: train/000000008131.jpg
#   inflating: train/000000008350.jpg
#   inflating: train/000000008351.jpg
#  extracting: train/000000008787.jpg
#  extracting: train/000000009002.jpg
#   inflating: train/000000009041.jpg
#   inflating: train/000000009170.jpg
#  extracting: train/000000009236.jpg
#   inflating: train/000000009466.jpg
#   inflating: train/000000009801.jpg
#   inflating: train/000000009807.jpg
#  extracting: train/000000009830.jpg
#   inflating: train/000000010107.jpg
#  extracting: train/000000010219.jpg
#   inflating: train/000000010324.jpg
#   inflating: train/000000010694.jpg
#   inflating: train/000000011169.jpg
#   inflating: train/000000011696.jpg
#   inflating: train/000000012085.jpg
#   inflating: train/000000012443.jpg
#   inflating: train/000000012764.jpg
#   inflating: train/000000012827.jpg
#   inflating: train/000000012966.jpg
#  extracting: train/000000013383.jpg
#  extracting: train/000000013636.jpg
#   inflating: train/000000013882.jpg
#   inflating: train/000000014108.jpg
#  extracting: train/000000014285.jpg
#   inflating: train/000000014681.jpg
#  extracting: train/000000014940.jpg
#   inflating: train/000000015070.jpg
#  extracting: train/000000015140.jpg
#   inflating: train/000000015267.jpg
#   inflating: train/000000015567.jpg
#   inflating: train/000000015978.jpg
#   inflating: train/000000016025.jpg
#   inflating: train/000000016164.jpg
#   inflating: train/000000016180.jpg
#   inflating: train/000000016377.jpg
#   inflating: train/000000016730.jpg
#   inflating: train/000000016759.jpg
#  extracting: train/000000016761.jpg
#   inflating: train/000000016775.jpg
#   inflating: train/000000016875.jpg
#   inflating: train/000000017179.jpg
#   inflating: train/000000017350.jpg
#   inflating: train/000000017655.jpg
#   inflating: train/000000017667.jpg
#  extracting: train/000000017923.jpg
#   inflating: train/000000018098.jpg
#   inflating: train/000000018148.jpg
#   inflating: train/000000018149.jpg
#  extracting: train/000000018783.jpg
#  extracting: train/000000018893.jpg
#  extracting: train/000000018903.jpg
#  extracting: train/000000019304.jpg
#  extracting: train/000000019308.jpg
#  extracting: train/000000019322.jpg
#   inflating: train/000000020207.jpg
#   inflating: train/000000020307.jpg
#   inflating: train/000000020438.jpg
#   inflating: train/000000020671.jpg
#   inflating: train/000000020748.jpg
#   inflating: train/000000021161.jpg
#   inflating: train/000000021396.jpg
#  extracting: train/000000022129.jpg
#   inflating: train/000000022599.jpg
#   inflating: train/000000022759.jpg
#   inflating: train/000000022874.jpg
#  extracting: train/000000023579.jpg
#   inflating: train/000000023656.jpg
#   inflating: train/000000023731.jpg
#  extracting: train/000000023917.jpg
#  extracting: train/000000024247.jpg
#   inflating: train/000000025123.jpg
#   inflating: train/000000025138.jpg
#  extracting: train/000000025551.jpg
#   inflating: train/000000025989.jpg
#  extracting: train/000000026371.jpg
#   inflating: train/000000026393.jpg
#   inflating: train/000000026654.jpg
#   inflating: train/000000026671.jpg
#   inflating: train/000000026730.jpg
#   inflating: train/000000026734.jpg
#   inflating: train/000000026768.jpg
#   inflating: train/000000026803.jpg
#   inflating: train/000000026908.jpg
#   inflating: train/000000026942.jpg
#   inflating: train/000000027075.jpg
#   inflating: train/000000027463.jpg
#   inflating: train/000000027519.jpg
#  extracting: train/000000027617.jpg
#   inflating: train/000000028273.jpg
#   inflating: train/000000028359.jpg
#   inflating: train/000000028714.jpg
#   inflating: train/000000028874.jpg
#   inflating: train/000000028903.jpg
#   inflating: train/000000029306.jpg
#   inflating: train/000000029370.jpg
#   inflating: train/000000029587.jpg
#  extracting: train/000000030156.jpg
#  extracting: train/000000030356.jpg
#   inflating: train/000000030607.jpg
#  extracting: train/000000030611.jpg
#   inflating: train/000000030657.jpg
#   inflating: train/000000030667.jpg
#  extracting: train/000000031049.jpg
#   inflating: train/000000031176.jpg
#   inflating: train/000000031345.jpg
#   inflating: train/000000031392.jpg
#  extracting: train/000000031745.jpg
#   inflating: train/000000031893.jpg
#   inflating: train/000000032054.jpg
#  extracting: train/000000032597.jpg
#  extracting: train/000000032677.jpg
#  extracting: train/000000032892.jpg
#  extracting: train/000000033008.jpg
#  extracting: train/000000033325.jpg
#   inflating: train/000000033377.jpg
#   inflating: train/000000033405.jpg
#   inflating: train/000000033900.jpg
#  extracting: train/000000033924.jpg
#   inflating: train/000000034321.jpg
#   inflating: train/000000034691.jpg
#  extracting: train/000000034773.jpg
#   inflating: train/000000035074.jpg
#   inflating: train/000000035438.jpg
#   inflating: train/000000035489.jpg
#   inflating: train/000000035672.jpg
#   inflating: train/000000035894.jpg
#   inflating: train/000000036124.jpg
#  extracting: train/000000036277.jpg
#   inflating: train/000000036451.jpg
#   inflating: train/000000036484.jpg
#   inflating: train/000000036713.jpg
#  extracting: train/000000036942.jpg
#  extracting: train/000000036962.jpg
#   inflating: train/000000037017.jpg
#   inflating: train/000000037470.jpg
#  extracting: train/000000037707.jpg
#  extracting: train/000000037729.jpg
#   inflating: train/000000037871.jpg
#  extracting: train/000000037907.jpg
#   inflating: train/000000038031.jpg
#  extracting: train/000000038438.jpg
#   inflating: train/000000038769.jpg
#  extracting: train/000000038837.jpg
#   inflating: train/000000038938.jpg
#   inflating: train/000000039368.jpg
#  extracting: train/000000039589.jpg
#   inflating: train/000000039718.jpg
#  extracting: train/000000039828.jpg
#  extracting: train/000000040042.jpg
#  extracting: train/000000040414.jpg
#   inflating: train/000000040842.jpg
#   inflating: train/000000041257.jpg
#   inflating: train/000000041265.jpg
#  extracting: train/000000041271.jpg
#   inflating: train/000000041273.jpg
#  extracting: train/000000041322.jpg
#  extracting: train/000000041373.jpg
#   inflating: train/000000042225.jpg
#   inflating: train/000000042421.jpg
#  extracting: train/000000042576.jpg
#   inflating: train/000000042856.jpg
#  extracting: train/000000042956.jpg
#   inflating: train/000000043289.jpg
#   inflating: train/000000043345.jpg
#   inflating: train/000000043433.jpg
#   inflating: train/000000043585.jpg
#  extracting: train/000000043712.jpg
#   inflating: train/000000043734.jpg
#   inflating: train/000000043850.jpg
#   inflating: train/000000043851.jpg
#   inflating: train/000000044022.jpg
#   inflating: train/000000044328.jpg
#  extracting: train/000000044347.jpg
#   inflating: train/000000044856.jpg
#  extracting: train/000000044950.jpg
#   inflating: train/000000045040.jpg
#  extracting: train/000000045108.jpg
#   inflating: train/000000045175.jpg
#   inflating: train/000000045176.jpg
#   inflating: train/000000045197.jpg
#   inflating: train/000000045208.jpg
#  extracting: train/000000045367.jpg
#   inflating: train/000000045586.jpg
#   inflating: train/000000045587.jpg
#   inflating: train/000000045603.jpg
#   inflating: train/000000045655.jpg
#  extracting: train/000000045721.jpg
#   inflating: train/000000045830.jpg
#  extracting: train/000000045882.jpg
#  extracting: train/000000046316.jpg
#   inflating: train/000000046345.jpg
#   inflating: train/000000046877.jpg
#   inflating: train/000000046905.jpg
#   inflating: train/000000047263.jpg
#   inflating: train/000000047367.jpg
#   inflating: train/000000047425.jpg
#   inflating: train/000000047724.jpg
#  extracting: train/000000047916.jpg
#  extracting: train/000000048014.jpg
#   inflating: train/000000048419.jpg
#  extracting: train/000000048530.jpg
#   inflating: train/000000048731.jpg
#   inflating: train/000000049097.jpg
#   inflating: train/000000051095.jpg
#   inflating: train/000000051272.jpg
#   inflating: train/000000051403.jpg
#  extracting: train/000000051746.jpg
#   inflating: train/000000051844.jpg
#   inflating: train/000000051880.jpg
#  extracting: train/000000052290.jpg
#   inflating: train/000000052637.jpg
#   inflating: train/000000052925.jpg
#  extracting: train/000000053289.jpg
#   inflating: train/000000053457.jpg
#  extracting: train/000000053484.jpg
#   inflating: train/000000053629.jpg
#   inflating: train/000000053677.jpg
#   inflating: train/000000054334.jpg
#   inflating: train/000000054340.jpg
#   inflating: train/000000054603.jpg
#  extracting: train/000000054643.jpg
#   inflating: train/000000054655.jpg
#   inflating: train/000000055126.jpg
#   inflating: train/000000055466.jpg
#   inflating: train/000000055840.jpg
#   inflating: train/000000056158.jpg
#   inflating: train/000000056373.jpg
#   inflating: train/000000056541.jpg
#   inflating: train/000000056646.jpg
#   inflating: train/000000056898.jpg
#  extracting: train/000000057460.jpg
#   inflating: train/000000057703.jpg
#   inflating: train/000000057812.jpg
#  extracting: train/000000057936.jpg
#  extracting: train/000000058001.jpg
#  extracting: train/000000058139.jpg
#  extracting: train/000000058849.jpg
#  extracting: train/000000059501.jpg
#   inflating: train/000000059652.jpg
#  extracting: train/000000059815.jpg
#  extracting: train/000000059949.jpg
#   inflating: train/000000060202.jpg
#  extracting: train/000000060792.jpg
#   inflating: train/000000061025.jpg
#   inflating: train/000000061492.jpg
#   inflating: train/000000061794.jpg
#   inflating: train/000000062167.jpg
#   inflating: train/000000062347.jpg
#  extracting: train/000000062398.jpg
#   inflating: train/000000062875.jpg
#  extracting: train/000000063040.jpg
#   inflating: train/000000063647.jpg
#   inflating: train/000000063950.jpg
#  extracting: train/000000063970.jpg
#   inflating: train/000000064710.jpg
#   inflating: train/000000065394.jpg
#   inflating: train/000000065430.jpg
#   inflating: train/000000065433.jpg
#   inflating: train/000000065443.jpg
#   inflating: train/000000066011.jpg
#   inflating: train/000000066271.jpg
#   inflating: train/000000066355.jpg
#   inflating: train/000000066413.jpg
#   inflating: train/000000066499.jpg
#   inflating: train/000000066556.jpg
#  extracting: train/000000066827.jpg
#   inflating: train/000000066960.jpg
#  extracting: train/000000067106.jpg
#  extracting: train/000000067122.jpg
#   inflating: train/000000067164.jpg
#  extracting: train/000000067207.jpg
#  extracting: train/000000067307.jpg
#   inflating: train/000000067532.jpg
#   inflating: train/000000067995.jpg
#  extracting: train/000000068005.jpg
#   inflating: train/000000068878.jpg
#  extracting: train/000000069000.jpg
#   inflating: train/000000069021.jpg
#  extracting: train/000000069077.jpg
#   inflating: train/000000069959.jpg
#   inflating: train/000000070353.jpg
#   inflating: train/000000070493.jpg
#   inflating: train/000000070528.jpg
#   inflating: train/000000070815.jpg
#  extracting: train/000000071004.jpg
#  extracting: train/000000071090.jpg
#   inflating: train/000000071283.jpg
#   inflating: train/000000071673.jpg
#   inflating: train/000000071687.jpg
#  extracting: train/000000071964.jpg
#  extracting: train/000000072810.jpg
#   inflating: train/000000073467.jpg
#  extracting: train/000000073729.jpg
#   inflating: train/000000073861.jpg
#  extracting: train/000000074001.jpg
#  extracting: train/000000074013.jpg
#   inflating: train/000000074030.jpg
#   inflating: train/000000074035.jpg
#  extracting: train/000000074268.jpg
#   inflating: train/000000074583.jpg
#   inflating: train/000000075055.jpg
#   inflating: train/000000075283.jpg
#  extracting: train/000000075344.jpg
#   inflating: train/000000075576.jpg
#  extracting: train/000000075591.jpg
#   inflating: train/000000075673.jpg
#   inflating: train/000000075742.jpg
#   inflating: train/000000075768.jpg
#   inflating: train/000000076522.jpg
#   inflating: train/000000076588.jpg
#  extracting: train/000000076619.jpg
#   inflating: train/000000077689.jpg
#   inflating: train/000000078026.jpg
#   inflating: train/000000078107.jpg
#   inflating: train/000000078188.jpg
#  extracting: train/000000078495.jpg
#  extracting: train/000000078689.jpg
#   inflating: train/000000078741.jpg
#  extracting: train/000000078771.jpg
#  extracting: train/000000078941.jpg
#   inflating: train/000000079407.jpg
#   inflating: train/000000079966.jpg
#   inflating: train/000000080213.jpg
#   inflating: train/000000080646.jpg
#  extracting: train/000000080757.jpg
#  extracting: train/000000081035.jpg
#   inflating: train/000000081552.jpg
#   inflating: train/000000081918.jpg
#   inflating: train/000000082042.jpg
#  extracting: train/000000082312.jpg
#   inflating: train/000000082680.jpg
#  extracting: train/000000082709.jpg
#  extracting: train/000000082826.jpg
#   inflating: train/000000082835.jpg
#   inflating: train/000000083476.jpg
#   inflating: train/000000084124.jpg
#   inflating: train/000000084312.jpg
#  extracting: train/000000084530.jpg
#  extracting: train/000000084749.jpg
#   inflating: train/000000084783.jpg
#   inflating: train/000000084859.jpg
#   inflating: train/000000084980.jpg
#   inflating: train/000000085131.jpg
#   inflating: train/000000086136.jpg
#   inflating: train/000000086168.jpg
#   inflating: train/000000086215.jpg
#   inflating: train/000000087377.jpg
#  extracting: train/000000087456.jpg
#   inflating: train/000000087595.jpg
#   inflating: train/000000087718.jpg
#   inflating: train/000000088784.jpg
#  extracting: train/000000089109.jpg
#  extracting: train/000000089188.jpg
#   inflating: train/000000089225.jpg
#  extracting: train/000000089430.jpg
#   inflating: train/000000089555.jpg
#  extracting: train/000000090010.jpg
#  extracting: train/000000090349.jpg
#   inflating: train/000000090366.jpg
#   inflating: train/000000090367.jpg
#  extracting: train/000000090540.jpg
#   inflating: train/000000090659.jpg
#   inflating: train/000000090754.jpg
#   inflating: train/000000091304.jpg
#  extracting: train/000000091334.jpg
#   inflating: train/000000091343.jpg
#  extracting: train/000000091612.jpg
#   inflating: train/000000091839.jpg
#  extracting: train/000000091885.jpg
#   inflating: train/000000092173.jpg
#   inflating: train/000000092202.jpg
#  extracting: train/000000092795.jpg
#  extracting: train/000000092801.jpg
#  extracting: train/000000093034.jpg
#   inflating: train/000000093201.jpg
#   inflating: train/000000093297.jpg
#   inflating: train/000000093360.jpg
#  extracting: train/000000093853.jpg
#   inflating: train/000000093948.jpg
#  extracting: train/000000094021.jpg
#   inflating: train/000000094140.jpg
#   inflating: train/000000094271.jpg
#   inflating: train/000000094376.jpg
#   inflating: train/000000094536.jpg
#   inflating: train/000000094566.jpg
#  extracting: train/000000094651.jpg
#   inflating: train/000000094823.jpg
#   inflating: train/000000094922.jpg
#  extracting: train/000000095805.jpg
#   inflating: train/000000096097.jpg
#   inflating: train/000000096288.jpg
#   inflating: train/000000096517.jpg
#   inflating: train/000000096618.jpg
#   inflating: train/000000096785.jpg
#  extracting: train/000000096983.jpg
#   inflating: train/000000097156.jpg
#   inflating: train/000000097580.jpg
#  extracting: train/000000098194.jpg
#   inflating: train/000000098284.jpg
#   inflating: train/000000098302.jpg
#   inflating: train/000000098871.jpg
#  extracting: train/000000099230.jpg
#   inflating: train/000000099269.jpg
#   inflating: train/000000099543.jpg
#   inflating: train/000000099645.jpg
#   inflating: train/000000099807.jpg
#   inflating: train/000000099874.jpg
#   inflating: train/000000099996.jpg
#  extracting: train/000000100000.jpg
#   inflating: train/000000100008.jpg
#   inflating: train/000000100196.jpg
#   inflating: train/000000100500.jpg
#   inflating: train/000000101567.jpg
#   inflating: train/000000102367.jpg
#  extracting: train/000000102421.jpg
#   inflating: train/000000102555.jpg
#   inflating: train/000000102598.jpg
#   inflating: train/000000102735.jpg
#   inflating: train/000000103127.jpg
#   inflating: train/000000103584.jpg
#   inflating: train/000000103757.jpg
#   inflating: train/000000103806.jpg
#   inflating: train/000000103873.jpg
#   inflating: train/000000104137.jpg
#   inflating: train/000000104150.jpg
#  extracting: train/000000104421.jpg
#   inflating: train/000000104494.jpg
#   inflating: train/000000104625.jpg
#   inflating: train/000000105120.jpg
#   inflating: train/000000105611.jpg
#  extracting: train/000000105658.jpg
#   inflating: train/000000105918.jpg
#   inflating: train/000000106166.jpg
#   inflating: train/000000106484.jpg
#  extracting: train/000000106624.jpg
#  extracting: train/000000106900.jpg
#  extracting: train/000000107375.jpg
#   inflating: train/000000107542.jpg
#  extracting: train/000000108315.jpg
#   inflating: train/000000108668.jpg
#   inflating: train/000000108681.jpg
#  extracting: train/000000108698.jpg
#  extracting: train/000000108761.jpg
#   inflating: train/000000108923.jpg
#  extracting: train/000000109291.jpg
#   inflating: train/000000109393.jpg
#  extracting: train/000000109498.jpg
#   inflating: train/000000109612.jpg
#   inflating: train/000000109869.jpg
#   inflating: train/000000109907.jpg
#   inflating: train/000000110435.jpg
#  extracting: train/000000110762.jpg
#  extracting: train/000000111548.jpg
#   inflating: train/000000111970.jpg
#   inflating: train/000000112342.jpg
#   inflating: train/000000112388.jpg
#  extracting: train/000000112677.jpg
#  extracting: train/000000112719.jpg
#  extracting: train/000000112770.jpg
#   inflating: train/000000112830.jpg
#   inflating: train/000000113271.jpg
#   inflating: train/000000113461.jpg
#   inflating: train/000000113678.jpg
#  extracting: train/000000113707.jpg
#  extracting: train/000000113975.jpg
#   inflating: train/000000114119.jpg
#   inflating: train/000000114239.jpg
#   inflating: train/000000114504.jpg
#   inflating: train/000000114726.jpg
#   inflating: train/000000114891.jpg
#  extracting: train/000000115070.jpg
#  extracting: train/000000115721.jpg
#  extracting: train/000000115859.jpg
#   inflating: train/000000115912.jpg
#  extracting: train/000000116061.jpg
#   inflating: train/000000116503.jpg
#   inflating: train/000000117328.jpg
#   inflating: train/000000117407.jpg
#   inflating: train/000000117690.jpg
#   inflating: train/000000117891.jpg
#  extracting: train/000000118546.jpg
#   inflating: train/000000118929.jpg
#   inflating: train/000000119081.jpg
#   inflating: train/000000119120.jpg
#   inflating: train/000000119360.jpg
#   inflating: train/000000120099.jpg
#   inflating: train/000000120129.jpg
#  extracting: train/000000120747.jpg
#  extracting: train/000000120860.jpg
#   inflating: train/000000120874.jpg
#   inflating: train/000000121112.jpg
#   inflating: train/000000121443.jpg
#   inflating: train/000000121547.jpg
#   inflating: train/000000121783.jpg
#   inflating: train/000000122213.jpg
#   inflating: train/000000122390.jpg
#   inflating: train/000000122458.jpg
#   inflating: train/000000122934.jpg
#  extracting: train/000000122953.jpg
#  extracting: train/000000123220.jpg
#  extracting: train/000000123867.jpg
#   inflating: train/000000123964.jpg
#  extracting: train/000000124002.jpg
#   inflating: train/000000124116.jpg
#  extracting: train/000000124429.jpg
#  extracting: train/000000124462.jpg
#   inflating: train/000000124729.jpg
#   inflating: train/000000124985.jpg
#   inflating: train/000000125100.jpg
#   inflating: train/000000125107.jpg
#   inflating: train/000000125291.jpg
#   inflating: train/000000125635.jpg
#   inflating: train/000000126145.jpg
#   inflating: train/000000126324.jpg
#   inflating: train/000000126538.jpg
#  extracting: train/000000126540.jpg
#   inflating: train/000000127313.jpg
#   inflating: train/000000127477.jpg
#   inflating: train/000000127556.jpg
#   inflating: train/000000127573.jpg
#  extracting: train/000000127659.jpg
#   inflating: train/000000127749.jpg
#   inflating: train/000000127781.jpg
#   inflating: train/000000127854.jpg
#   inflating: train/000000128528.jpg
#   inflating: train/000000128679.jpg
#   inflating: train/000000129139.jpg
#   inflating: train/000000129187.jpg
#  extracting: train/000000129339.jpg
#  extracting: train/000000129864.jpg
#   inflating: train/000000130399.jpg
#   inflating: train/000000130522.jpg
#  extracting: train/000000130921.jpg
#   inflating: train/000000131497.jpg
#   inflating: train/000000131714.jpg
#   inflating: train/000000132389.jpg
#   inflating: train/000000132578.jpg
#  extracting: train/000000132690.jpg
#  extracting: train/000000132733.jpg
#   inflating: train/000000133251.jpg
#  extracting: train/000000133608.jpg
#   inflating: train/000000133690.jpg
#  extracting: train/000000133707.jpg
#   inflating: train/000000135116.jpg
#   inflating: train/000000135158.jpg
#  extracting: train/000000135275.jpg
#  extracting: train/000000135748.jpg
#   inflating: train/000000136250.jpg
#   inflating: train/000000136720.jpg
#   inflating: train/000000137028.jpg
#   inflating: train/000000137057.jpg
#   inflating: train/000000137188.jpg
#   inflating: train/000000137321.jpg
#   inflating: train/000000137412.jpg
#   inflating: train/000000137413.jpg
#  extracting: train/000000137507.jpg
#  extracting: train/000000137595.jpg
#   inflating: train/000000137861.jpg
#   inflating: train/000000137961.jpg
#   inflating: train/000000138070.jpg
#  extracting: train/000000138083.jpg
#   inflating: train/000000139475.jpg
#   inflating: train/000000139721.jpg
#  extracting: train/000000139781.jpg
#  extracting: train/000000140444.jpg
#   inflating: train/000000141086.jpg
#  extracting: train/000000141172.jpg
#  extracting: train/000000141524.jpg
#  extracting: train/000000141538.jpg
#  extracting: train/000000142454.jpg
#   inflating: train/000000142484.jpg
#  extracting: train/000000142719.jpg
#   inflating: train/000000142722.jpg
#   inflating: train/000000142744.jpg
#  extracting: train/000000142769.jpg
#   inflating: train/000000142890.jpg
#   inflating: train/000000142891.jpg
#   inflating: train/000000143792.jpg
#   inflating: train/000000143824.jpg
#  extracting: train/000000143825.jpg
#   inflating: train/000000143876.jpg
#   inflating: train/000000144723.jpg
#   inflating: train/000000144862.jpg
#   inflating: train/000000145101.jpg
#  extracting: train/000000145312.jpg
#   inflating: train/000000145448.jpg
#   inflating: train/000000145512.jpg
#   inflating: train/000000145544.jpg
#   inflating: train/000000145567.jpg
#  extracting: train/000000145668.jpg
#   inflating: train/000000145815.jpg
#   inflating: train/000000146334.jpg
#   inflating: train/000000146411.jpg
#   inflating: train/000000146767.jpg
#  extracting: train/000000146981.jpg
#  extracting: train/000000147259.jpg
#   inflating: train/000000147425.jpg
#  extracting: train/000000147471.jpg
#   inflating: train/000000147629.jpg
#   inflating: train/000000147787.jpg
#   inflating: train/000000148193.jpg
#   inflating: train/000000148272.jpg
#   inflating: train/000000148458.jpg
#   inflating: train/000000148737.jpg
#   inflating: train/000000148968.jpg
#   inflating: train/000000149005.jpg
#   inflating: train/000000149184.jpg
#   inflating: train/000000149446.jpg
#   inflating: train/000000149646.jpg
#  extracting: train/000000150235.jpg
#  extracting: train/000000150413.jpg
#   inflating: train/000000150558.jpg
#   inflating: train/000000151537.jpg
#   inflating: train/000000151585.jpg
#   inflating: train/000000151988.jpg
#   inflating: train/000000152103.jpg
#   inflating: train/000000153150.jpg
#   inflating: train/000000153692.jpg
#  extracting: train/000000153783.jpg
#   inflating: train/000000153966.jpg
#   inflating: train/000000154053.jpg
#  extracting: train/000000154057.jpg
#   inflating: train/000000154254.jpg
#   inflating: train/000000154419.jpg
#  extracting: train/000000154589.jpg
#  extracting: train/000000154701.jpg
#   inflating: train/000000155012.jpg
#  extracting: train/000000155199.jpg
#   inflating: train/000000155974.jpg
#  extracting: train/000000155997.jpg
#   inflating: train/000000156025.jpg
#   inflating: train/000000156102.jpg
#  extracting: train/000000156458.jpg
#   inflating: train/000000156620.jpg
#   inflating: train/000000157099.jpg
#   inflating: train/000000157405.jpg
#   inflating: train/000000157469.jpg
#  extracting: train/000000157876.jpg
#   inflating: train/000000158109.jpg
#  extracting: train/000000158127.jpg
#  extracting: train/000000158354.jpg
#   inflating: train/000000158384.jpg
#   inflating: train/000000158497.jpg
#  extracting: train/000000158798.jpg
#   inflating: train/000000159170.jpg
#  extracting: train/000000159463.jpg
#   inflating: train/000000159944.jpg
#   inflating: train/000000160211.jpg
#   inflating: train/000000160501.jpg
#   inflating: train/000000161141.jpg
#   inflating: train/000000161144.jpg
#   inflating: train/000000161220.jpg
#  extracting: train/000000161505.jpg
#   inflating: train/000000161557.jpg
#   inflating: train/000000161736.jpg
#   inflating: train/000000161840.jpg
#   inflating: train/000000162256.jpg
#  extracting: train/000000163127.jpg
#   inflating: train/000000163496.jpg
#   inflating: train/000000163575.jpg
#   inflating: train/000000163666.jpg
#   inflating: train/000000163684.jpg
#   inflating: train/000000163728.jpg
#   inflating: train/000000163777.jpg
#   inflating: train/000000163782.jpg
#   inflating: train/000000163831.jpg
#  extracting: train/000000164186.jpg
#   inflating: train/000000165035.jpg
#   inflating: train/000000165752.jpg
#  extracting: train/000000166037.jpg
#   inflating: train/000000166995.jpg
#  extracting: train/000000167017.jpg
#  extracting: train/000000167501.jpg
#   inflating: train/000000167602.jpg
#   inflating: train/000000167802.jpg
#  extracting: train/000000167874.jpg
#  extracting: train/000000168031.jpg
#   inflating: train/000000168146.jpg
#   inflating: train/000000168375.jpg
#  extracting: train/000000168425.jpg
#   inflating: train/000000168543.jpg
#  extracting: train/000000168698.jpg
#   inflating: train/000000168812.jpg
#   inflating: train/000000168817.jpg
#   inflating: train/000000168834.jpg
#   inflating: train/000000168847.jpg
#   inflating: train/000000169347.jpg
#   inflating: train/000000169361.jpg
#   inflating: train/000000169800.jpg
#   inflating: train/000000170517.jpg
#  extracting: train/000000170898.jpg
#   inflating: train/000000171058.jpg
#   inflating: train/000000171062.jpg
#   inflating: train/000000171494.jpg
#  extracting: train/000000171539.jpg
#  extracting: train/000000171595.jpg
#   inflating: train/000000171753.jpg
#   inflating: train/000000171809.jpg
#   inflating: train/000000171880.jpg
#  extracting: train/000000172597.jpg
#   inflating: train/000000172993.jpg
#  extracting: train/000000173350.jpg
#   inflating: train/000000173400.jpg
#  extracting: train/000000173825.jpg
#   inflating: train/000000173832.jpg
#   inflating: train/000000173907.jpg
#   inflating: train/000000174113.jpg
#   inflating: train/000000174871.jpg
#  extracting: train/000000175494.jpg
#  extracting: train/000000175729.jpg
#   inflating: train/000000176078.jpg
#   inflating: train/000000176474.jpg
#   inflating: train/000000176697.jpg
#   inflating: train/000000177258.jpg
#  extracting: train/000000177262.jpg
#  extracting: train/000000177323.jpg
#   inflating: train/000000177486.jpg
#   inflating: train/000000177529.jpg
#   inflating: train/000000177842.jpg
#  extracting: train/000000177913.jpg
#   inflating: train/000000178299.jpg
#   inflating: train/000000178616.jpg
#  extracting: train/000000178761.jpg
#   inflating: train/000000178939.jpg
#   inflating: train/000000178941.jpg
#  extracting: train/000000178948.jpg
#   inflating: train/000000179069.jpg
#   inflating: train/000000179441.jpg
#   inflating: train/000000179725.jpg
#  extracting: train/000000179954.jpg
#   inflating: train/000000180373.jpg
#  extracting: train/000000180738.jpg
#   inflating: train/000000180830.jpg
#   inflating: train/000000181169.jpg
#  extracting: train/000000181449.jpg
#  extracting: train/000000181586.jpg
#   inflating: train/000000181739.jpg
#   inflating: train/000000181763.jpg
#  extracting: train/000000181963.jpg
#   inflating: train/000000182683.jpg
#   inflating: train/000000182696.jpg
#   inflating: train/000000182759.jpg
#  extracting: train/000000182867.jpg
#   inflating: train/000000182903.jpg
#   inflating: train/000000183199.jpg
#  extracting: train/000000183571.jpg
#  extracting: train/000000183757.jpg
#   inflating: train/000000183967.jpg
#   inflating: train/000000184557.jpg
#   inflating: train/000000184606.jpg
#   inflating: train/000000184771.jpg
#  extracting: train/000000185030.jpg
#   inflating: train/000000185156.jpg
#   inflating: train/000000185432.jpg
#   inflating: train/000000185550.jpg
#   inflating: train/000000185773.jpg
#   inflating: train/000000186412.jpg
#  extracting: train/000000186589.jpg
#   inflating: train/000000187177.jpg
#   inflating: train/000000187349.jpg
#   inflating: train/000000187432.jpg
#   inflating: train/000000188546.jpg
#   inflating: train/000000188651.jpg
#   inflating: train/000000188667.jpg
#   inflating: train/000000188824.jpg
#  extracting: train/000000189504.jpg
#   inflating: train/000000189600.jpg
#  extracting: train/000000189868.jpg
#  extracting: train/000000189939.jpg
#   inflating: train/000000189966.jpg
#   inflating: train/000000190156.jpg
#   inflating: train/000000190211.jpg
#  extracting: train/000000190326.jpg
#  extracting: train/000000190690.jpg
#   inflating: train/000000190760.jpg
#  extracting: train/000000191169.jpg
#  extracting: train/000000191280.jpg
#  extracting: train/000000191738.jpg
#   inflating: train/000000191964.jpg
#  extracting: train/000000193680.jpg
#  extracting: train/000000194120.jpg
#  extracting: train/000000194203.jpg
#  extracting: train/000000194306.jpg
#  extracting: train/000000194313.jpg
#   inflating: train/000000194420.jpg
#   inflating: train/000000194594.jpg
#   inflating: train/000000195297.jpg
#   inflating: train/000000195353.jpg
#   inflating: train/000000195437.jpg
#   inflating: train/000000195815.jpg
#  extracting: train/000000195817.jpg
#  extracting: train/000000195889.jpg
#  extracting: train/000000196371.jpg
#   inflating: train/000000196664.jpg
#  extracting: train/000000197097.jpg
#   inflating: train/000000197111.jpg
#   inflating: train/000000197245.jpg
#   inflating: train/000000197352.jpg
#  extracting: train/000000197458.jpg
#   inflating: train/000000197809.jpg
#   inflating: train/000000198176.jpg
#   inflating: train/000000198416.jpg
#   inflating: train/000000198518.jpg
#   inflating: train/000000198563.jpg
#   inflating: train/000000198612.jpg
#  extracting: train/000000198658.jpg
#   inflating: train/000000198724.jpg
#  extracting: train/000000198935.jpg
#   inflating: train/000000199449.jpg
#   inflating: train/000000199575.jpg
#   inflating: train/000000199641.jpg
#   inflating: train/000000199940.jpg
#   inflating: train/000000200023.jpg
#   inflating: train/000000200492.jpg
#   inflating: train/000000200572.jpg
#   inflating: train/000000200681.jpg
#   inflating: train/000000200870.jpg
#   inflating: train/000000201190.jpg
#  extracting: train/000000201348.jpg
#   inflating: train/000000201918.jpg
#   inflating: train/000000202275.jpg
#   inflating: train/000000202582.jpg
#  extracting: train/000000203292.jpg
#   inflating: train/000000203463.jpg
#   inflating: train/000000205054.jpg
#  extracting: train/000000205103.jpg
#  extracting: train/000000205350.jpg
#   inflating: train/000000205378.jpg
#   inflating: train/000000205523.jpg
#   inflating: train/000000205531.jpg
#  extracting: train/000000205573.jpg
#   inflating: train/000000205854.jpg
#   inflating: train/000000206417.jpg
#   inflating: train/000000207093.jpg
#   inflating: train/000000207509.jpg
#   inflating: train/000000207557.jpg
#   inflating: train/000000207925.jpg
#   inflating: train/000000208236.jpg
#   inflating: train/000000208861.jpg
#  extracting: train/000000209028.jpg
#   inflating: train/000000209286.jpg
#   inflating: train/000000209289.jpg
#   inflating: train/000000209299.jpg
#  extracting: train/000000209419.jpg
#  extracting: train/000000209468.jpg
#   inflating: train/000000210012.jpg
#  extracting: train/000000210060.jpg
#   inflating: train/000000210144.jpg
#  extracting: train/000000210276.jpg
#   inflating: train/000000210958.jpg
#  extracting: train/000000212470.jpg
#   inflating: train/000000212545.jpg
#   inflating: train/000000212603.jpg
#   inflating: train/000000212605.jpg
#  extracting: train/000000213799.jpg
#   inflating: train/000000214184.jpg
#   inflating: train/000000214306.jpg
#   inflating: train/000000214671.jpg
#   inflating: train/000000214984.jpg
#  extracting: train/000000215353.jpg
#   inflating: train/000000215394.jpg
#   inflating: train/000000215424.jpg
#   inflating: train/000000215471.jpg
#   inflating: train/000000215554.jpg
#  extracting: train/000000215579.jpg
#   inflating: train/000000215652.jpg
#   inflating: train/000000215949.jpg
#   inflating: train/000000216014.jpg
#   inflating: train/000000216051.jpg
#   inflating: train/000000216103.jpg
#  extracting: train/000000216161.jpg
#   inflating: train/000000216273.jpg
#   inflating: train/000000216417.jpg
#   inflating: train/000000216428.jpg
#   inflating: train/000000216548.jpg
#  extracting: train/000000216664.jpg
#   inflating: train/000000216861.jpg
#  extracting: train/000000216944.jpg
#   inflating: train/000000217082.jpg
#   inflating: train/000000217521.jpg
#  extracting: train/000000217923.jpg
#   inflating: train/000000218214.jpg
#   inflating: train/000000218561.jpg
#   inflating: train/000000218924.jpg
#   inflating: train/000000219063.jpg
#   inflating: train/000000219492.jpg
#   inflating: train/000000219567.jpg
#   inflating: train/000000219632.jpg
#   inflating: train/000000219798.jpg
#   inflating: train/000000219894.jpg
#   inflating: train/000000220053.jpg
#  extracting: train/000000220266.jpg
#  extracting: train/000000220292.jpg
#  extracting: train/000000221523.jpg
#   inflating: train/000000221776.jpg
#  extracting: train/000000221966.jpg
#  extracting: train/000000222043.jpg
#  extracting: train/000000222146.jpg
#  extracting: train/000000222195.jpg
#  extracting: train/000000222228.jpg
#   inflating: train/000000222467.jpg
#   inflating: train/000000223032.jpg
#  extracting: train/000000223413.jpg
#   inflating: train/000000223626.jpg
#   inflating: train/000000223757.jpg
#  extracting: train/000000223833.jpg
#  extracting: train/000000224567.jpg
#   inflating: train/000000224793.jpg
#   inflating: train/000000224861.jpg
#  extracting: train/000000224974.jpg
#   inflating: train/000000225456.jpg
#   inflating: train/000000225919.jpg
#   inflating: train/000000226220.jpg
#   inflating: train/000000226291.jpg
#  extracting: train/000000226360.jpg
#   inflating: train/000000226376.jpg
#   inflating: train/000000226400.jpg
#   inflating: train/000000226938.jpg
#  extracting: train/000000226957.jpg
#  extracting: train/000000227218.jpg
#  extracting: train/000000227227.jpg
#   inflating: train/000000227428.jpg
#   inflating: train/000000227709.jpg
#   inflating: train/000000227730.jpg
#  extracting: train/000000227878.jpg
#  extracting: train/000000228309.jpg
#   inflating: train/000000228418.jpg
#  extracting: train/000000228506.jpg
#   inflating: train/000000228683.jpg
#  extracting: train/000000228746.jpg
#   inflating: train/000000228764.jpg
#   inflating: train/000000228854.jpg
#   inflating: train/000000229096.jpg
#  extracting: train/000000229139.jpg
#  extracting: train/000000229342.jpg
#  extracting: train/000000229387.jpg
#  extracting: train/000000229631.jpg
#  extracting: train/000000229740.jpg
#  extracting: train/000000229840.jpg
#  extracting: train/000000230150.jpg
#   inflating: train/000000230151.jpg
#  extracting: train/000000230220.jpg
#   inflating: train/000000230501.jpg
#   inflating: train/000000230619.jpg
#   inflating: train/000000231022.jpg
#   inflating: train/000000231408.jpg
#   inflating: train/000000231644.jpg
#   inflating: train/000000231655.jpg
#   inflating: train/000000231846.jpg
#   inflating: train/000000231895.jpg
#  extracting: train/000000231998.jpg
#   inflating: train/000000232383.jpg
#   inflating: train/000000232969.jpg
#  extracting: train/000000233005.jpg
#   inflating: train/000000233446.jpg
#   inflating: train/000000233660.jpg
#   inflating: train/000000234124.jpg
#   inflating: train/000000234136.jpg
#  extracting: train/000000234719.jpg
#  extracting: train/000000234785.jpg
#   inflating: train/000000235126.jpg
#   inflating: train/000000235203.jpg
#   inflating: train/000000235274.jpg
#   inflating: train/000000235790.jpg
#  extracting: train/000000236117.jpg
#   inflating: train/000000236162.jpg
#  extracting: train/000000236234.jpg
#  extracting: train/000000236747.jpg
#   inflating: train/000000236904.jpg
#   inflating: train/000000236945.jpg
#   inflating: train/000000236954.jpg
#   inflating: train/000000237399.jpg
#   inflating: train/000000237476.jpg
#   inflating: train/000000237764.jpg
#   inflating: train/000000237772.jpg
#   inflating: train/000000237881.jpg
#   inflating: train/000000237917.jpg
#  extracting: train/000000238291.jpg
#   inflating: train/000000238302.jpg
#  extracting: train/000000238377.jpg
#  extracting: train/000000238602.jpg
#   inflating: train/000000239048.jpg
#   inflating: train/000000239458.jpg
#   inflating: train/000000239985.jpg
#   inflating: train/000000240137.jpg
#   inflating: train/000000240217.jpg
#   inflating: train/000000240537.jpg
#   inflating: train/000000241279.jpg
#   inflating: train/000000241340.jpg
#   inflating: train/000000241503.jpg
#   inflating: train/000000241837.jpg
#  extracting: train/000000241876.jpg
#   inflating: train/000000241986.jpg
#  extracting: train/000000242007.jpg
#  extracting: train/000000242297.jpg
#  extracting: train/000000242510.jpg
#   inflating: train/000000242570.jpg
#  extracting: train/000000243218.jpg
#   inflating: train/000000243456.jpg
#  extracting: train/000000243912.jpg
#   inflating: train/000000244468.jpg
#   inflating: train/000000245006.jpg
#  extracting: train/000000245201.jpg
#  extracting: train/000000245462.jpg
#  extracting: train/000000245997.jpg
#   inflating: train/000000246076.jpg
#   inflating: train/000000246512.jpg
#   inflating: train/000000247206.jpg
#   inflating: train/000000247428.jpg
#   inflating: train/000000248206.jpg
#   inflating: train/000000248363.jpg
#   inflating: train/000000248381.jpg
#  extracting: train/000000248591.jpg
#   inflating: train/000000249599.jpg
#  extracting: train/000000249952.jpg
#   inflating: train/000000250022.jpg
#  extracting: train/000000250804.jpg
#   inflating: train/000000250924.jpg
#   inflating: train/000000250951.jpg
#  extracting: train/000000251627.jpg
#  extracting: train/000000251639.jpg
#   inflating: train/000000251716.jpg
#  extracting: train/000000251752.jpg
#  extracting: train/000000252127.jpg
#   inflating: train/000000252203.jpg
#  extracting: train/000000252573.jpg
#  extracting: train/000000252617.jpg
#   inflating: train/000000252745.jpg
#   inflating: train/000000253177.jpg
#  extracting: train/000000253624.jpg
#   inflating: train/000000253665.jpg
#   inflating: train/000000253988.jpg
#  extracting: train/000000254045.jpg
#   inflating: train/000000254050.jpg
#   inflating: train/000000254074.jpg
#   inflating: train/000000254392.jpg
#  extracting: train/000000254540.jpg
#  extracting: train/000000254609.jpg
#   inflating: train/000000254838.jpg
#   inflating: train/000000254976.jpg
#   inflating: train/000000255134.jpg
#   inflating: train/000000255244.jpg
#  extracting: train/000000256481.jpg
#   inflating: train/000000256577.jpg
#  extracting: train/000000256628.jpg
#   inflating: train/000000256657.jpg
#  extracting: train/000000256800.jpg
#  extracting: train/000000257036.jpg
#   inflating: train/000000257458.jpg
#   inflating: train/000000258523.jpg
#  extracting: train/000000258773.jpg
#   inflating: train/000000258789.jpg
#  extracting: train/000000258998.jpg
#   inflating: train/000000259112.jpg
#  extracting: train/000000259475.jpg
#  extracting: train/000000259819.jpg
#   inflating: train/000000259879.jpg
#   inflating: train/000000260699.jpg
#   inflating: train/000000260738.jpg
#   inflating: train/000000260967.jpg
#   inflating: train/000000261068.jpg
#   inflating: train/000000261333.jpg
#  extracting: train/000000261563.jpg
#   inflating: train/000000261758.jpg
#  extracting: train/000000261824.jpg
#   inflating: train/000000261981.jpg
#  extracting: train/000000262014.jpg
#   inflating: train/000000262371.jpg
#   inflating: train/000000262396.jpg
#   inflating: train/000000262626.jpg
#   inflating: train/000000262736.jpg
#   inflating: train/000000262758.jpg
#   inflating: train/000000263146.jpg
#   inflating: train/000000263493.jpg
#  extracting: train/000000263588.jpg
#  extracting: train/000000263612.jpg
#   inflating: train/000000264392.jpg
#  extracting: train/000000264660.jpg
#   inflating: train/000000264787.jpg
#   inflating: train/000000264976.jpg
#  extracting: train/000000265003.jpg
#   inflating: train/000000265313.jpg
#   inflating: train/000000265433.jpg
#   inflating: train/000000265707.jpg
#   inflating: train/000000265916.jpg
#   inflating: train/000000266250.jpg
#   inflating: train/000000266379.jpg
#  extracting: train/000000266627.jpg
#   inflating: train/000000267115.jpg
#   inflating: train/000000267321.jpg
#   inflating: train/000000267664.jpg
#   inflating: train/000000267725.jpg
#   inflating: train/000000268052.jpg
#   inflating: train/000000268885.jpg
#   inflating: train/000000269344.jpg
#   inflating: train/000000269417.jpg
#   inflating: train/000000269429.jpg
#  extracting: train/000000269511.jpg
#   inflating: train/000000269918.jpg
#   inflating: train/000000270148.jpg
#   inflating: train/000000270744.jpg
#   inflating: train/000000270785.jpg
#   inflating: train/000000271035.jpg
#   inflating: train/000000271359.jpg
#   inflating: train/000000271576.jpg
#  extracting: train/000000271588.jpg
#  extracting: train/000000271680.jpg
#  extracting: train/000000271785.jpg
#  extracting: train/000000271907.jpg
#   inflating: train/000000271943.jpg
#   inflating: train/000000272153.jpg
#   inflating: train/000000272241.jpg
#   inflating: train/000000272713.jpg
#   inflating: train/000000273083.jpg
#   inflating: train/000000273885.jpg
#  extracting: train/000000273930.jpg
#   inflating: train/000000274058.jpg
#   inflating: train/000000274292.jpg
#   inflating: train/000000274470.jpg
#   inflating: train/000000274800.jpg
#   inflating: train/000000275219.jpg
#   inflating: train/000000275253.jpg
#   inflating: train/000000275449.jpg
#  extracting: train/000000275542.jpg
#   inflating: train/000000275979.jpg
#   inflating: train/000000276693.jpg
#   inflating: train/000000276706.jpg
#  extracting: train/000000276719.jpg
#   inflating: train/000000276986.jpg
#   inflating: train/000000277235.jpg
#   inflating: train/000000277622.jpg
#   inflating: train/000000277793.jpg
#  extracting: train/000000278134.jpg
#  extracting: train/000000278184.jpg
#   inflating: train/000000278435.jpg
#   inflating: train/000000278550.jpg
#   inflating: train/000000279097.jpg
#   inflating: train/000000279159.jpg
#   inflating: train/000000279386.jpg
#   inflating: train/000000279463.jpg
#   inflating: train/000000279809.jpg
#   inflating: train/000000279919.jpg
#   inflating: train/000000279994.jpg
#  extracting: train/000000280709.jpg
#   inflating: train/000000280736.jpg
#  extracting: train/000000280858.jpg
#   inflating: train/000000281208.jpg
#   inflating: train/000000281296.jpg
#   inflating: train/000000281331.jpg
#   inflating: train/000000281424.jpg
#  extracting: train/000000281475.jpg
#   inflating: train/000000281533.jpg
#  extracting: train/000000281591.jpg
#   inflating: train/000000281598.jpg
#   inflating: train/000000281758.jpg
#   inflating: train/000000281977.jpg
#   inflating: train/000000282134.jpg
#   inflating: train/000000282155.jpg
#   inflating: train/000000282287.jpg
#   inflating: train/000000282591.jpg
#  extracting: train/000000282674.jpg
#   inflating: train/000000282768.jpg
#   inflating: train/000000283028.jpg
#  extracting: train/000000283119.jpg
#   inflating: train/000000283152.jpg
#   inflating: train/000000283210.jpg
#  extracting: train/000000283286.jpg
#   inflating: train/000000283471.jpg
#   inflating: train/000000283505.jpg
#  extracting: train/000000283627.jpg
#   inflating: train/000000283748.jpg
#   inflating: train/000000283833.jpg
#   inflating: train/000000283904.jpg
#   inflating: train/000000283910.jpg
#  extracting: train/000000283940.jpg
#   inflating: train/000000284488.jpg
#  extracting: train/000000284605.jpg
#  extracting: train/000000284641.jpg
#  extracting: train/000000284658.jpg
#   inflating: train/000000284715.jpg
#  extracting: train/000000284772.jpg
#   inflating: train/000000284851.jpg
#   inflating: train/000000285212.jpg
#  extracting: train/000000285258.jpg
#  extracting: train/000000285418.jpg
#  extracting: train/000000285421.jpg
#   inflating: train/000000285733.jpg
#   inflating: train/000000285968.jpg
#   inflating: train/000000286327.jpg
#   inflating: train/000000286480.jpg
#   inflating: train/000000287033.jpg
#  extracting: train/000000287331.jpg
#   inflating: train/000000288399.jpg
#   inflating: train/000000288579.jpg
#   inflating: train/000000288639.jpg
#   inflating: train/000000288776.jpg
#   inflating: train/000000288847.jpg
#  extracting: train/000000288955.jpg
#   inflating: train/000000289264.jpg
#  extracting: train/000000289523.jpg
#   inflating: train/000000289618.jpg
#   inflating: train/000000289716.jpg
#   inflating: train/000000290269.jpg
#   inflating: train/000000290355.jpg
#   inflating: train/000000290432.jpg
#  extracting: train/000000290521.jpg
#  extracting: train/000000290659.jpg
#  extracting: train/000000290750.jpg
#  extracting: train/000000290839.jpg
#   inflating: train/000000290868.jpg
#   inflating: train/000000291257.jpg
#   inflating: train/000000291394.jpg
#   inflating: train/000000291412.jpg
#  extracting: train/000000291541.jpg
#  extracting: train/000000292188.jpg
#   inflating: train/000000292232.jpg
#   inflating: train/000000292266.jpg
#  extracting: train/000000292365.jpg
#  extracting: train/000000292931.jpg
#  extracting: train/000000293027.jpg
#  extracting: train/000000293554.jpg
#  extracting: train/000000293757.jpg
#   inflating: train/000000295016.jpg
#   inflating: train/000000295051.jpg
#  extracting: train/000000295097.jpg
#   inflating: train/000000295693.jpg
#   inflating: train/000000296032.jpg
#   inflating: train/000000296056.jpg
# ...
#  extracting: train/000000523418.jpg
#   inflating: train/000000524245.jpg
#   inflating: train/000000524382.jpg
#   inflating: train/000000524665.jpg
#   inflating: train/000000525909.jpg
#   inflating: train/000000526414.jpg
#  extracting: train/000000526425.jpg
#   inflating: train/000000526671.jpg
#   inflating: train/000000526721.jpg
#   inflating: train/000000526962.jpg
#  extracting: train/000000527529.jpg
#   inflating: train/000000527670.jpg
#  extracting: train/000000527845.jpg
#  extracting: train/000000528251.jpg
#   inflating: train/000000528488.jpg
#   inflating: train/000000529256.jpg
#   inflating: train/000000529590.jpg
#   inflating: train/000000529626.jpg
#   inflating: train/000000529649.jpg
#   inflating: train/000000529850.jpg
#   inflating: train/000000529968.jpg
#  extracting: train/000000530367.jpg
#  extracting: train/000000530765.jpg
#  extracting: train/000000530913.jpg
#   inflating: train/000000531189.jpg
#   inflating: train/000000531414.jpg
#   inflating: train/000000531594.jpg
#  extracting: train/000000531710.jpg
#   inflating: train/000000531803.jpg
#   inflating: train/000000531983.jpg
#   inflating: train/000000531995.jpg
#   inflating: train/000000532381.jpg
#   inflating: train/000000532426.jpg
#   inflating: train/000000532693.jpg
#   inflating: train/000000533026.jpg
#  extracting: train/000000533156.jpg
#  extracting: train/000000533239.jpg
#   inflating: train/000000534252.jpg
#   inflating: train/000000534679.jpg
#   inflating: train/000000534829.jpg
#   inflating: train/000000534942.jpg
#   inflating: train/000000535080.jpg
#   inflating: train/000000535106.jpg
#  extracting: train/000000535226.jpg
#   inflating: train/000000535483.jpg
#   inflating: train/000000535602.jpg
#  extracting: train/000000535809.jpg
#   inflating: train/000000536154.jpg
#  extracting: train/000000536321.jpg
#   inflating: train/000000536400.jpg
#   inflating: train/000000537574.jpg
#   inflating: train/000000537604.jpg
#   inflating: train/000000537636.jpg
#   inflating: train/000000537955.jpg
#  extracting: train/000000538132.jpg
#   inflating: train/000000538586.jpg
#   inflating: train/000000539196.jpg
#   inflating: train/000000539238.jpg
#  extracting: train/000000539683.jpg
#  extracting: train/000000539971.jpg
#   inflating: train/000000540099.jpg
#   inflating: train/000000540449.jpg
#   inflating: train/000000540452.jpg
#  extracting: train/000000540669.jpg
#  extracting: train/000000540774.jpg
#  extracting: train/000000541053.jpg
#   inflating: train/000000541158.jpg
#   inflating: train/000000541267.jpg
#   inflating: train/000000542487.jpg
#  extracting: train/000000542939.jpg
#   inflating: train/000000543034.jpg
#   inflating: train/000000543264.jpg
#   inflating: train/000000543315.jpg
#  extracting: train/000000543497.jpg
#   inflating: train/000000543566.jpg
#   inflating: train/000000543686.jpg
#   inflating: train/000000543719.jpg
#   inflating: train/000000543836.jpg
#   inflating: train/000000543897.jpg
#  extracting: train/000000544122.jpg
#  extracting: train/000000544590.jpg
#   inflating: train/000000545093.jpg
#  extracting: train/000000545475.jpg
#  extracting: train/000000546210.jpg
#  extracting: train/000000546264.jpg
#  extracting: train/000000546378.jpg
#   inflating: train/000000546584.jpg
#   inflating: train/000000546622.jpg
#   inflating: train/000000546642.jpg
#   inflating: train/000000546702.jpg
#  extracting: train/000000546742.jpg
#  extracting: train/000000546792.jpg
#  extracting: train/000000546896.jpg
#   inflating: train/000000546962.jpg
#   inflating: train/000000547062.jpg
#   inflating: train/000000547413.jpg
#   inflating: train/000000547421.jpg
#   inflating: train/000000547607.jpg
#  extracting: train/000000548219.jpg
#   inflating: train/000000548331.jpg
#  extracting: train/000000548498.jpg
#   inflating: train/000000548500.jpg
#   inflating: train/000000549410.jpg
#   inflating: train/000000549649.jpg
#   inflating: train/000000549936.jpg
#   inflating: train/000000550013.jpg
#  extracting: train/000000550287.jpg
#   inflating: train/000000550713.jpg
#   inflating: train/000000551358.jpg
#   inflating: train/000000552061.jpg
#  extracting: train/000000552395.jpg
#   inflating: train/000000552829.jpg
#   inflating: train/000000552942.jpg
#   inflating: train/000000552979.jpg
#  extracting: train/000000553083.jpg
#   inflating: train/000000553436.jpg
#   inflating: train/000000553547.jpg
#   inflating: train/000000553698.jpg
#   inflating: train/000000553721.jpg
#   inflating: train/000000553761.jpg
#  extracting: train/000000553795.jpg
#   inflating: train/000000554377.jpg
#   inflating: train/000000554958.jpg
#  extracting: train/000000555298.jpg
#   inflating: train/000000555669.jpg
#   inflating: train/000000555684.jpg
#  extracting: train/000000556505.jpg
#   inflating: train/000000556758.jpg
#  extracting: train/000000556817.jpg
#   inflating: train/000000557239.jpg
#   inflating: train/000000557451.jpg
#   inflating: train/000000557543.jpg
#   inflating: train/000000558127.jpg
#   inflating: train/000000558350.jpg
#   inflating: train/000000558671.jpg
#   inflating: train/000000559047.jpg
#  extracting: train/000000559067.jpg
#   inflating: train/000000559388.jpg
#   inflating: train/000000559776.jpg
#  extracting: train/000000559778.jpg
#   inflating: train/000000559950.jpg
#   inflating: train/000000560222.jpg
#   inflating: train/000000560297.jpg
#   inflating: train/000000560373.jpg
#   inflating: train/000000560830.jpg
#  extracting: train/000000561062.jpg
#  extracting: train/000000561116.jpg
#  extracting: train/000000561393.jpg
#  extracting: train/000000561411.jpg
#   inflating: train/000000561599.jpg
#   inflating: train/000000561766.jpg
#   inflating: train/000000561780.jpg
#  extracting: train/000000561903.jpg
#   inflating: train/000000561979.jpg
#   inflating: train/000000562150.jpg
#   inflating: train/000000562289.jpg
#   inflating: train/000000562370.jpg
#  extracting: train/000000562645.jpg
#   inflating: train/000000562875.jpg
#   inflating: train/000000563009.jpg
#   inflating: train/000000563337.jpg
#   inflating: train/000000563403.jpg
#   inflating: train/000000563723.jpg
#   inflating: train/000000564301.jpg
#   inflating: train/000000565087.jpg
#   inflating: train/000000565341.jpg
#   inflating: train/000000565797.jpg
#  extracting: train/000000565954.jpg
#   inflating: train/000000566027.jpg
#   inflating: train/000000566264.jpg
#  extracting: train/000000566644.jpg
#   inflating: train/000000566656.jpg
#   inflating: train/000000566717.jpg
#   inflating: train/000000566998.jpg
#   inflating: train/000000567142.jpg
#  extracting: train/000000567535.jpg
#   inflating: train/000000567603.jpg
#   inflating: train/000000568238.jpg
#  extracting: train/000000568508.jpg
#   inflating: train/000000568559.jpg
#   inflating: train/000000569249.jpg
#  extracting: train/000000569272.jpg
#   inflating: train/000000569333.jpg
#  extracting: train/000000569729.jpg
#  extracting: train/000000569773.jpg
#  extracting: train/000000570077.jpg
#  extracting: train/000000570107.jpg
#   inflating: train/000000570115.jpg
#   inflating: train/000000570521.jpg
#  extracting: train/000000570528.jpg
#   inflating: train/000000570952.jpg
#   inflating: train/000000570995.jpg
#  extracting: train/000000571544.jpg
#  extracting: train/000000571823.jpg
#   inflating: train/000000571835.jpg
#   inflating: train/000000572042.jpg
#   inflating: train/000000572050.jpg
#   inflating: train/000000572075.jpg
#   inflating: train/000000572184.jpg
#  extracting: train/000000572370.jpg
#   inflating: train/000000572702.jpg
#   inflating: train/000000573181.jpg
#   inflating: train/000000573753.jpg
#   inflating: train/000000573759.jpg
#   inflating: train/000000573877.jpg
#  extracting: train/000000573881.jpg
#  extracting: train/000000573896.jpg
#   inflating: train/000000573935.jpg
#  extracting: train/000000574184.jpg
#  extracting: train/000000574208.jpg
#   inflating: train/000000574241.jpg
#   inflating: train/000000574350.jpg
#   inflating: train/000000574706.jpg
#  extracting: train/000000574769.jpg
#   inflating: train/000000574834.jpg
#  extracting: train/000000575219.jpg
#   inflating: train/000000575882.jpg
#   inflating: train/000000575911.jpg
#   inflating: train/000000575957.jpg
#   inflating: train/000000576136.jpg
#  extracting: train/000000576191.jpg
#   inflating: train/000000576513.jpg
#   inflating: train/000000576701.jpg
#  extracting: train/000000577028.jpg
#   inflating: train/000000577526.jpg
#   inflating: train/000000578088.jpg
#   inflating: train/000000578441.jpg
#   inflating: train/000000578632.jpg
#   inflating: train/000000578776.jpg
#  extracting: train/000000579008.jpg
#   inflating: train/000000579760.jpg
#   inflating: train/000000579822.jpg
#  extracting: train/000000579911.jpg
#   inflating: train/000000580255.jpg
#   inflating: train/000000580540.jpg
#  extracting: train/000000581033.jpg
#   inflating: train/000000581157.jpg
#   inflating: train/000000581402.jpg
#  extracting: train/000000581654.jpg
#  extracting: train/000000581717.jpg
#  extracting: val/000000004795.jpg
#   inflating: val/000000007386.jpg
#   inflating: val/000000010363.jpg
#   inflating: val/000000022192.jpg
#  extracting: val/000000023272.jpg
#   inflating: val/000000025560.jpg
#  extracting: val/000000029393.jpg
#  extracting: val/000000046378.jpg
#   inflating: val/000000047121.jpg
#   inflating: val/000000049269.jpg
#   inflating: val/000000051008.jpg
#   inflating: val/000000053529.jpg
#   inflating: val/000000060835.jpg
#   inflating: val/000000061108.jpg
#   inflating: val/000000061471.jpg
#  extracting: val/000000065485.jpg
#   inflating: val/000000067213.jpg
#   inflating: val/000000068078.jpg
#  extracting: val/000000071226.jpg
#   inflating: val/000000076417.jpg
#   inflating: val/000000077396.jpg
#  extracting: val/000000078420.jpg
#   inflating: val/000000078565.jpg
#  extracting: val/000000078823.jpg
#  extracting: val/000000079229.jpg
#   inflating: val/000000080666.jpg
#   inflating: val/000000081766.jpg
#  extracting: val/000000088951.jpg
#   inflating: val/000000089880.jpg
#   inflating: val/000000101762.jpg
#   inflating: val/000000107087.jpg
#  extracting: val/000000108244.jpg
#  extracting: val/000000109055.jpg
#   inflating: val/000000112798.jpg
#   inflating: val/000000116825.jpg
#  extracting: val/000000117525.jpg
#   inflating: val/000000118515.jpg
#  extracting: val/000000125850.jpg
#   inflating: val/000000126110.jpg
#   inflating: val/000000129756.jpg
#  extracting: val/000000131273.jpg
#  extracting: val/000000134096.jpg
#   inflating: val/000000139099.jpg
#   inflating: val/000000139872.jpg
#   inflating: val/000000140203.jpg
#   inflating: val/000000149222.jpg
#   inflating: val/000000153217.jpg
#   inflating: val/000000155291.jpg
#   inflating: val/000000157807.jpg
#   inflating: val/000000161609.jpg
#   inflating: val/000000163155.jpg
#   inflating: val/000000166277.jpg
#  extracting: val/000000167122.jpg
#   inflating: val/000000169076.jpg
#   inflating: val/000000170893.jpg
#   inflating: val/000000171611.jpg
#   inflating: val/000000172330.jpg
#   inflating: val/000000176778.jpg
#   inflating: val/000000176857.jpg
#  extracting: val/000000187236.jpg
#   inflating: val/000000189806.jpg
#   inflating: val/000000190140.jpg
#  extracting: val/000000193162.jpg
#   inflating: val/000000198641.jpg
#  extracting: val/000000205834.jpg
#   inflating: val/000000206831.jpg
#   inflating: val/000000209613.jpg
#   inflating: val/000000209747.jpg
#   inflating: val/000000211042.jpg
#   inflating: val/000000213445.jpg
#   inflating: val/000000219485.jpg
#   inflating: val/000000219578.jpg
#   inflating: val/000000222317.jpg
#   inflating: val/000000223747.jpg
#  extracting: val/000000224200.jpg
#   inflating: val/000000225184.jpg
#  extracting: val/000000227044.jpg
#   inflating: val/000000231831.jpg
#   inflating: val/000000235399.jpg
#   inflating: val/000000236166.jpg
#   inflating: val/000000237864.jpg
#  extracting: val/000000240940.jpg
#  extracting: val/000000241326.jpg
#   inflating: val/000000245764.jpg
#   inflating: val/000000246454.jpg
#   inflating: val/000000251572.jpg
#  extracting: val/000000255965.jpg
#  extracting: val/000000260925.jpg
#   inflating: val/000000261161.jpg
#   inflating: val/000000261706.jpg
#   inflating: val/000000264441.jpg
#  extracting: val/000000267300.jpg
#  extracting: val/000000277584.jpg
#   inflating: val/000000278463.jpg
#  extracting: val/000000279145.jpg
#  extracting: val/000000279278.jpg
#   inflating: val/000000284623.jpg
#   inflating: val/000000286422.jpg
#  extracting: val/000000286708.jpg
#   inflating: val/000000288685.jpg
#   inflating: val/000000289343.jpg
#   inflating: val/000000291664.jpg
#   inflating: val/000000292330.jpg
#   inflating: val/000000297085.jpg
#  extracting: val/000000300913.jpg
#   inflating: val/000000304560.jpg
#   inflating: val/000000305343.jpg
#   inflating: val/000000311190.jpg
#   inflating: val/000000312213.jpg
#   inflating: val/000000312340.jpg
#  extracting: val/000000316015.jpg
#   inflating: val/000000318908.jpg
#  extracting: val/000000320554.jpg
#  extracting: val/000000327769.jpg
#   inflating: val/000000329219.jpg
#   inflating: val/000000329319.jpg
#  extracting: val/000000347930.jpg
#   inflating: val/000000350054.jpg
#  extracting: val/000000353970.jpg
#   inflating: val/000000357941.jpg
#   inflating: val/000000360943.jpg
#   inflating: val/000000361571.jpg
#   inflating: val/000000361621.jpg
#   inflating: val/000000365207.jpg
#  extracting: val/000000366884.jpg
#  extracting: val/000000372819.jpg
#  extracting: val/000000375278.jpg
#   inflating: val/000000375493.jpg
#   inflating: val/000000377575.jpg
#   inflating: val/000000386457.jpg
#   inflating: val/000000387383.jpg
#   inflating: val/000000392818.jpg
#   inflating: val/000000399560.jpg
#  extracting: val/000000401991.jpg
#   inflating: val/000000402473.jpg
#   inflating: val/000000404484.jpg
#   inflating: val/000000405306.jpg
#   inflating: val/000000407083.jpg
#   inflating: val/000000409867.jpg
#   inflating: val/000000411665.jpg
#  extracting: val/000000412240.jpg
#   inflating: val/000000415990.jpg
#   inflating: val/000000419974.jpg
#   inflating: val/000000424162.jpg
#   inflating: val/000000432468.jpg
#  extracting: val/000000432553.jpg
#   inflating: val/000000452891.jpg
#  extracting: val/000000456292.jpg
#   inflating: val/000000460841.jpg
#  extracting: val/000000466156.jpg
#   inflating: val/000000466339.jpg
#   inflating: val/000000472375.jpg
#   inflating: val/000000474164.jpg
#  extracting: val/000000475732.jpg
#   inflating: val/000000478393.jpg
#   inflating: val/000000482917.jpg
#   inflating: val/000000489014.jpg
#   inflating: val/000000491216.jpg
#   inflating: val/000000492284.jpg
#   inflating: val/000000494634.jpg
#   inflating: val/000000494869.jpg
#   inflating: val/000000498286.jpg
#   inflating: val/000000501523.jpg
#   inflating: val/000000505573.jpg
#   inflating: val/000000515025.jpg
#  extracting: val/000000520301.jpg
#   inflating: val/000000530099.jpg
#  extracting: val/000000532530.jpg
#   inflating: val/000000532575.jpg
#   inflating: val/000000534270.jpg
#   inflating: val/000000540928.jpg
#   inflating: val/000000546829.jpg
#   inflating: val/000000551815.jpg
#   inflating: val/000000554002.jpg
#   inflating: val/000000554291.jpg
#   inflating: val/000000555705.jpg
#   inflating: val/000000558073.jpg
#  extracting: val/000000565391.jpg
#   inflating: val/000000565962.jpg
#   inflating: val/000000568690.jpg
#   inflating: val/000000579321.jpg

# %%
#os = Operating System, 여기선 운영체제에 맞게 경로 생성해줌
#torch = pytorch 사용, 파이토치는 인공신경망을 만드는데 필요한 다양한 기본 요소를 간단하고 직관적이며 안정적인 API로 제공함
#PIL = Python Imaging Library, 파이썬 이미지 처리 라이브러리
#pycocotools.coco = COCO 데이터 셋을 활용하기 위한 여러 유용한 함수들을 제공(e.g. getAnnIds, getCatIds etc)
#torch.utils.data = 파이토치의 데이터 불러오는 역할 수행

import os
import torch
from PIL import Image
from pycocotools.coco import COCO
from torch.utils.data import Dataset

#coco dataset 다루는 클래스
class COCODataset(Dataset):
    #어노테이션, image path 등 준비, transform은 데이터 변형 및 데이터 증강을 말하는데 데이터 변형 안함(transform = None)
    def __init__(self, root, train, transform=None):
        super().__init__()
        directory = "train" if train else "val"
        annotations = os.path.join(root, "annotations", f"{directory}_annotations.json")

        self.coco = COCO(annotations)
        self.iamge_path = os.path.join(root, directory)
        self.transform = transform

        self.categories = self._get_categories()
        self.data = self._load_data()

    #카테고리 설정
    def _get_categories(self):
        categories = {0: "background"}
        for category in self.coco.cats.values():
            categories[category["id"]] = category["name"]
        return categories

    #이미지 불러오기
    def _load_data(self):
        data = []
        for _id in self.coco.imgs:
            file_name = self.coco.loadImgs(_id)[0]["file_name"]
            image_path = os.path.join(self.iamge_path, file_name)
            image = Image.open(image_path).convert("RGB")

            boxes = []
            labels = []
            anns = self.coco.loadAnns(self.coco.getAnnIds(_id))

            #박스와 레이블 만들기
            for ann in anns:
                x, y, w, h = ann["bbox"]

                boxes.append([x, y, x + w, y + h])
                labels.append(ann["category_id"])

            #ground truth(supervised learning에서 정한 이미 정해놓은 박스)가 target로 나옴
            target = {
                "image_id": torch.LongTensor([_id]),
                "boxes": torch.FloatTensor(boxes),
                "labels": torch.LongTensor(labels)
            }
            data.append([image, target])
        return data

    #데이터 아이템(이미지, ground truth box)을 뽑기
    def __getitem__(self, index):
        image, target = self.data[index]
        if self.transform:
            image = self.transform(image)
        return image, target

    #데이터 크기 찾기
    def __len__(self):
        return len(self.data)

# %%
#torchvision = 파이토치에서 이미지 데이터의 전처리 및 데이터 증강을 위해 제공하는 모듈
from torchvision import transforms
from torch.utils.data import DataLoader

#배치를 만들기 위해 데이터들을 합쳐주는 함수(collate = 합치다)
#zip = 여러 개의 리스트나 튜플 타입을 합쳐 새로운 튜플(tuple) 타입으로 반환
def collator(batch):
    return tuple(zip(*batch))

#이미지를 변환시켜주기, 이미지를 텐서로 만듦(데이터 타입은 torch.float로 나오게 함)
#e.g. torch.FloatTensor([[1,2], [3,4]]) -> tensor([[1., 2.],[3., 4.]])
transform = transforms.Compose(
    [
        transforms.PILToTensor(),
        transforms.ConvertImageDtype(dtype=torch.float)
    ]
)

#validation data를 test_dataset으로 넣어줌
test_dataset = COCODataset("/content/val", train=False, transform=transform)

#train_dataloader과 test_dataloader의 batch_size 1로 설정해줌, 데이터 shuffle해놓음.??
train_dataloader = DataLoader(
    test_dataset, batch_size=1, shuffle=True, drop_last=True, collate_fn=collator
)
test_dataloader = DataLoader(
    test_dataset, batch_size=1, shuffle=True, drop_last=True, collate_fn=collator
)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
#rpn = region proposal network
from torchvision import models
from torchvision import ops
from torchvision.models.detection import rpn
from torchvision.models.detection import FasterRCNN

#백본은 VGG16(Very Deep Convolutional Networks For Large-Scale Image Recognition)을 사용
#VGG16은 16개의 레이어로 구성(13개 convolution layers, 3개 fully connected layers, 완전신경망, 한층의 모든 뉴런이 다음 층의 모든 뉴런에 연결된 것)
#VGG16은 convolution filter를 3x3로 구성.
#VGG16의 아웃풋 채널은 512.??
#VGG 논문이해 -> https://medium.com/@msmapark2/vgg16-%EB%85%BC%EB%AC%B8-%EB%A6%AC%EB%B7%B0-very-deep-convolutional-networks-for-large-scale-image-recognition-6f748235242a
backbone = models.vgg16(weights="VGG16_Weights.IMAGENET1K_V1").features
backbone.out_channels = 512

#앵커박스 만들기 -> 책 p.513, 그림 9.6
anchor_generator = rpn.AnchorGenerator(
    sizes=((32, 64, 128, 256, 512),),
    aspect_ratios=((0.5, 1.0, 2.0),)
)

#관심영역풀링(ROI pooling) -> 고정된 크기의 특징 맵 얻음. 이 특징 맵을 완전 연결 계층에 전달해 물체의 클래스와 위치 예측.??
roi_pooler = ops.MultiScaleRoIAlign(
    featmap_names=["0"],
    output_size=(7, 7),
    sampling_ratio=2
)

#gpu 사용하면 cuda 아니면 cpu사용.
device = "cuda" if torch.cuda.is_available() else "cpu"

#우리가 만드는 FasterRCNN모델의 구조, num_classes는 background, cat, dog임.
model = FasterRCNN(
    backbone=backbone,
    num_classes=3,
    rpn_anchor_generator=anchor_generator,
    box_roi_pool=roi_pooler
).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:03<00:00, 159MB/s]

# %%
#optim은 최적화 알고리즘을 구현하는 패키지
from torch import optim

#requires_grad가 True이면 모델 파라미터들을 optimizer에서 업데이트해줌.
#optimizer에서 weight_decay를 하는 이유는 과적합을 막기위해. weight 너무 커져서 모델이 너무 복잡해지지 않도록 함(https://light-tree.tistory.com/216)
#weight decay는 L1 Regularization 또는 L2 Regularization 등이 쓰임.
#lr_schedular step size마다 gamma 비율로 lr를 감소시킨다(https://wikidocs.net/157282)
params = [p for p in model.parameters() if p.requires_grad]
optimizer = optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
#Python3, CPU, 고용량 RAM, 도서관 Public Wifi Free에서 약 3시간 소요
#모델 트레이닝
for epoch in range(5):
    cost = 0.0
    for idx, (images, targets) in enumerate(train_dataloader): # validation data가 181개, 그래서 181 iterations
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets) # L_cls, L_reg?
        #print("loss_dict", loss_dict) 시간될 때 뭐 나오나 확인해보기??
        losses = sum(loss for loss in loss_dict.values())

        #한번의 학습이 완료되면(iteration 완료 시), gradients를 0으로 만들어줌
        optimizer.zero_grad()
        #역전파 적용, loss 함수 기록
        losses.backward()
        #최적화 알고리즘 적용하여 필요 시, 파라미터(weight, bias) 업데이트(Loss 함수 작아지면 업데이트)
        optimizer.step()

        cost += losses

    lr_scheduler.step()
    cost = cost / len(train_dataloader) # 181
    print(f"Epoch : {epoch+1:4d}, Cost : {cost:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a4e1d1d0d401> in <cell line: 3>()
#       3 for epoch in range(5):
#       4     cost = 0.0
# ----> 5     for idx, (images, targets) in enumerate(train_dataloader): # 181 iters
#       6         images = list(image.to(device) for image in images)
#       7         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#
# NameError: name 'train_dataloader' is not defined

# %%
#Python3, CPU, 고용량 RAM, 도서관 Public Wifi Free에서 11분 걸림
#matplotlib는 파이썬에서 데이터 시각화해주는 라이브러리
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
from torchvision.transforms.functional import to_pil_image


def draw_bbox(ax, box, text, color):
    #bounding box 그리기
    ax.add_patch(
        plt.Rectangle(
            xy=(box[0], box[1]),
            width=box[2] - box[0],
            height=box[3] - box[1],
            fill=False,
            edgecolor=color,
            linewidth=2,
        )
    )
    #bounding box의 annotation 그리기
    ax.annotate(
        text=text,
        xy=(box[0] - 5, box[1] - 5),
        color=color,
        weight="bold",
        fontsize=13,
    )

#IoU(Intersection over Union)의 threshold를 0.5로 설정 (p.516 참조)
threshold = 0.5
categories = test_dataset.categories
with torch.no_grad():
    model.eval()
    for images, targets in test_dataloader: # 181 iters
        images = [image.to(device) for image in images]
        outputs = model(images)

        boxes = outputs[0]["boxes"].to("cpu").numpy()
        labels = outputs[0]["labels"].to("cpu").numpy()
        scores = outputs[0]["scores"].to("cpu").numpy()

        #IoU에서 threshold가 0.5이상일 때만 boxes, labels, scores 기록, 나중에 빨간색 박스로 그림에서 나옴
        boxes = boxes[scores >= threshold].astype(np.int32)
        labels = labels[scores >= threshold]
        scores = scores[scores >= threshold]

        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(1, 1, 1)
        plt.imshow(to_pil_image(images[0]))

        #우리 모델이 훈련한 box를 빨간색으로 나오게 함
        for box, label, score in zip(boxes, labels, scores):
            draw_bbox(ax, box, f"{categories[label]} - {score:.4f}", "red")

        tboxes = targets[0]["boxes"].numpy()
        tlabels = targets[0]["labels"].numpy()

        #ground truth는 파란색 box로 나오게 함.
        for box, label in zip(tboxes, tlabels):
            draw_bbox(ax, box, f"{categories[label]}", "blue")

        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Python3, CPU, 고용량 RAM, 도서관 Public Wifi Free에서 9분 걸림
import numpy as np
from pycocotools.cocoeval import COCOeval


with torch.no_grad():
  #모델을 evaluation함
    model.eval()
    coco_detections = []
    for images, targets in test_dataloader:
        images = [img.to(device) for img in images]
        outputs = model(images)

        #boxes 왜 세개임??
        for i in range(len(targets)):
            image_id = targets[i]["image_id"].data.cpu().numpy().tolist()[0]
            boxes = outputs[i]["boxes"].data.cpu().numpy()
            boxes[:, 2] = boxes[:, 2] - boxes[:, 0]
            boxes[:, 3] = boxes[:, 3] - boxes[:, 1]
            scores = outputs[i]["scores"].data.cpu().numpy()
            labels = outputs[i]["labels"].data.cpu().numpy()

            #boxes 왜 세개임??
            for instance_id in range(len(boxes)):
                box = boxes[instance_id, :].tolist()
                prediction = np.array(
                    [
                        image_id,
                        box[0],
                        box[1],
                        box[2],
                        box[3],
                        float(scores[instance_id]),
                        int(labels[instance_id]),
                    ]
                )
                coco_detections.append(prediction)

    coco_detections = np.asarray(coco_detections)
    coco_gt = test_dataloader.dataset.coco
    coco_dt = coco_gt.loadRes(coco_detections)
    coco_evaluator = COCOeval(coco_gt, coco_dt, iouType="bbox")
    coco_evaluator.evaluate()
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
# Out:
# Loading and preparing results...
# Converting ndarray to lists...
# (2354, 7)
# 0/2354
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.376
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.467
